# %%
url = 'https://www.nbastuffer.com/2021-2022-nba-player-stats/'
import pandas as pd

# %%
df = pd.read_html(url, header = 0)
df
# Out:
# [     RANK          FULL NAME TEAM  POS    AGE  GP   MPG  \
#  0     NaN   Precious Achiuwa  Tor    F  22.24  21  26.5
#  1     NaN       Steven Adams  Mem    C  28.41  29  24.9
#  2     NaN        Bam Adebayo  Mia  C-F  24.41  18  32.9
#  3     NaN       Santi Aldama  Mem  F-C  20.93  16   9.7
#  4     NaN  LaMarcus Aldridge  Bro  C-F  36.41  25  23.6
#  ..    ...                ...  ...  ...    ...  ..   ...
#  476   NaN         Trae Young  Atl    G  23.24  28  34.2
#  477   NaN     Omer Yurtseven  Mia    C  23.49  20   7.2
#  478   NaN        Cody Zeller  Por  F-C  29.20  24  13.3
#  479   NaN        Ivica Zubac  Lac    C  24.75  29  24.8
#  480   NaN      Scottie Lewis  Cha    G  21.76   2   3.3
#
#       MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
#  0                                                 55.2
#  1                                                 52.0
#  2                                                 68.5
# ...

# %%
len(df)
# Out:
# 1

# %%
df = df[0]

# %%
df
# Out:
#      RANK          FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0     NaN   Precious Achiuwa  Tor    F  22.24  21  26.5
# 1     NaN       Steven Adams  Mem    C  28.41  29  24.9
# 2     NaN        Bam Adebayo  Mia  C-F  24.41  18  32.9
# 3     NaN       Santi Aldama  Mem  F-C  20.93  16   9.7
# 4     NaN  LaMarcus Aldridge  Bro  C-F  36.41  25  23.6
# ..    ...                ...  ...  ...    ...  ..   ...
# 476   NaN         Trae Young  Atl    G  23.24  28  34.2
# 477   NaN     Omer Yurtseven  Mia    C  23.49  20   7.2
# 478   NaN        Cody Zeller  Por  F-C  29.20  24  13.3
# 479   NaN        Ivica Zubac  Lac    C  24.75  29  24.8
# 480   NaN      Scottie Lewis  Cha    G  21.76   2   3.3
#
#      MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                                 55.2
# 1                                                 52.0
# 2                                                 68.5
# ...

# %%
df = df.drop(["RANK"],axis=1)
df
# Out:
#              FULL NAME TEAM  POS    AGE  GP   MPG  \
# 0     Precious Achiuwa  Tor    F  22.24  21  26.5
# 1         Steven Adams  Mem    C  28.41  29  24.9
# 2          Bam Adebayo  Mia  C-F  24.41  18  32.9
# 3         Santi Aldama  Mem  F-C  20.93  16   9.7
# 4    LaMarcus Aldridge  Bro  C-F  36.41  25  23.6
# ..                 ...  ...  ...    ...  ..   ...
# 476         Trae Young  Atl    G  23.24  28  34.2
# 477     Omer Yurtseven  Mia    C  23.49  20   7.2
# 478        Cody Zeller  Por  F-C  29.20  24  13.3
# 479        Ivica Zubac  Lac    C  24.75  29  24.8
# 480      Scottie Lewis  Cha    G  21.76   2   3.3
#
#      MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                                 55.2
# 1                                                 52.0
# 2                                                 68.5
# 3                                                 20.3
# ...

# %%
df['AGE']=df['AGE'].astype(int)
df.head()
# Out:
#            FULL NAME TEAM  POS  AGE  GP   MPG  \
# 0   Precious Achiuwa  Tor    F   22  21  26.5
# 1       Steven Adams  Mem    C   28  29  24.9
# 2        Bam Adebayo  Mia  C-F   24  18  32.9
# 3       Santi Aldama  Mem  F-C   20  16   9.7
# 4  LaMarcus Aldridge  Bro  C-F   36  25  23.6
#
#    MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor  \
# 0                                               55.2
# 1                                               52.0
# 2                                               68.5
# 3                                               20.3
# 4                                               49.2
#
#    USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor  \
# 0                                               17.2
# 1                                               13.4
# 2                                               26.0
# ...

# %%
#Renaming Columns
df = df.rename(columns={"AST%Assist PercentageAssist percentage is an estimated percentage of teammate field goals a player assisted while the player is on the court": "AST%", "SPGStealsSteals per game.": "SPG","BPGBlocksBlocks per game.": "BPG", "TOPGTurnoversTurnovers per game.": "TOPG","VIVersatility IndexVersatility index is a metric that measures a player’s ability to produce in points, assists, and rebounds. The average player will score around a five on the index, while top players score above 10": "VI", "ORTGOffensive RatingIndividual offensive rating is the number of points produced by a player per 100 total individual possessions.": "ORTG","DRTGDefensive RatingIndividual defensive rating estimates how many points the player allowed per 100 possessions he individually faced while staying on the court.": "DRTG",'MIN%Minutes PercentagePercentage of team minutes used by a player while he was on the floor': 'MIN%','USG%Usage RateUsage rate, a.k.a., usage percentage is an estimate of the percentage of team plays used by a player while he was on the floor': 'USG%','TO%Turnover RateA metric that estimates the number of turnovers a player commits per 100 possessions': 'TO%','eFG%Effective Shooting PercentageWith eFG%, three-point shots made are worth 50% more than two-point shots made. eFG% Formula=(FGM+ (0.5 x 3PM))/FGA': 'eFG%','TS%True Shooting PercentageTrue shooting percentage is a measure of shooting efficiency that takes into account field goals, 3-point field goals, and free throws.': 'TS%','PPGPointsPoints per game.': 'PPG','RPGReboundsRebounds per game.': 'RPG','TRB%Total Rebound PercentageTotal rebound percentage is estimated percentage of available rebounds grabbed by the player while the player is on the court.': 'TRB%','APGAssistsAssists per game.': 'APG',})
df.columns
# Out:
# Index(['FULL NAME', 'TEAM', 'POS', 'AGE', 'GP', 'MPG', 'MIN%', 'USG%', 'TO%',
#        'FTA', 'FT%', '2PA', '2P%', '3PA', '3P%', 'eFG%', 'TS%', 'PPG', 'RPG',
#        'TRB%', 'APG', 'AST%', 'SPG', 'BPG', 'TOPG', 'VI', 'ORTG', 'DRTG'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# FULL NAME     0
# TEAM          0
# POS           0
# AGE           0
# GP            0
# MPG           0
# MIN%          0
# USG%          0
# TO%           9
# FTA           0
# FT%           0
# 2PA           0
# 2P%           0
# 3PA           0
# 3P%           0
# eFG%         11
# TS%          10
# PPG           0
# RPG           0
# TRB%          0
# APG           0
# AST%          0
# SPG           0
# BPG           0
# TOPG          0
# VI            0
# ORTG         42
# DRTG         42
# dtype: int64

# %%
df.loc[:,df.isna().any()]
# Out:
#       TO%   eFG%    TS%   ORTG   DRTG
# 0    10.3  0.405  0.421   96.4  101.4
# 1    22.2  0.535  0.570  118.1  105.6
# 2    15.3  0.519  0.577  111.0   96.6
# 3     6.6  0.386  0.407   98.2  103.1
# 4     6.3  0.594  0.621  121.4  102.6
# ..    ...    ...    ...    ...    ...
# 476  15.0  0.528  0.585  116.1  111.2
# 477  12.5  0.521  0.554  111.8   98.8
# 478  14.2  0.566  0.631  130.1   98.0
# 479  16.0  0.665  0.707  133.1   97.3
# 480   0.0    NaN  0.568    NaN    NaN
#
# [481 rows x 5 columns]

# %%
df.iloc[480]
# Out:
# FULL NAME    Scottie Lewis
# TEAM                   Cha
# POS                      G
# AGE                     21
# GP                       2
# MPG                    3.3
# MIN%                   6.9
# USG%                   5.7
# TO%                    0.0
# FTA                      2
# FT%                    0.5
# 2PA                      0
# 2P%                    0.0
# 3PA                      0
# 3P%                    0.0
# eFG%                   NaN
# TS%                  0.568
# PPG                    0.5
# RPG                    0.0
# TRB%                   0.0
# APG                    0.5
# AST%                  17.2
# SPG                    0.5
# BPG                    0.0
# TOPG                   0.0
# VI                     0.0
# ORTG                   NaN
# DRTG                   NaN
# Name: 480, dtype: object

# %%
df = df.fillna(0)

# %%
df.iloc[480]
# Out:
# FULL NAME    Scottie Lewis
# TEAM                   Cha
# POS                      G
# AGE                     21
# GP                       2
# MPG                    3.3
# MIN%                   6.9
# USG%                   5.7
# TO%                    0.0
# FTA                      2
# FT%                    0.5
# 2PA                      0
# 2P%                    0.0
# 3PA                      0
# 3P%                    0.0
# eFG%                   0.0
# TS%                  0.568
# PPG                    0.5
# RPG                    0.0
# TRB%                   0.0
# APG                    0.5
# AST%                  17.2
# SPG                    0.5
# BPG                    0.0
# TOPG                   0.0
# VI                     0.0
# ORTG                   0.0
# DRTG                   0.0
# Name: 480, dtype: object

# %%
df.loc[4]
# Out:
# FULL NAME    LaMarcus Aldridge
# TEAM                       Bro
# POS                        C-F
# AGE                         36
# GP                          25
# MPG                       23.6
# MIN%                      49.2
# USG%                      22.2
# TO%                        6.3
# FTA                         48
# FT%                      0.833
# 2PA                        230
# 2P%                        0.6
# 3PA                         30
# 3P%                      0.367
# eFG%                     0.594
# TS%                      0.621
# PPG                       14.0
# RPG                        5.7
# TRB%                      12.8
# APG                        0.9
# AST%                       6.6
# SPG                        0.4
# BPG                       1.16
# TOPG                      0.76
# VI                         7.0
# ORTG                     121.4
# DRTG                     102.6
# Name: 4, dtype: object

# %%
df.TEAM.unique()
# Out:
# array(['Tor', 'Mem', 'Mia', 'Bro', 'Nor', 'Mil', 'Cle', 'Lal', 'Orl',
#        'Hou', 'Was', 'Pho', 'Uta', 'Sac', 'Cha', 'Chi', 'Nyk', 'Den',
#        'Phi', 'San', 'Lac', 'Okc', 'Min', 'Det', 'Ind', 'Gol', 'Por',
#        'Atl', 'Bos', 'Dal'], dtype=object)

# %%
df["TEAM"] = df["TEAM"].str.upper()
df["TEAM"].unique()
# Out:
# array(['TOR', 'MEM', 'MIA', 'BRO', 'NOR', 'MIL', 'CLE', 'LAL', 'ORL',
#        'HOU', 'WAS', 'PHO', 'UTA', 'SAC', 'CHA', 'CHI', 'NYK', 'DEN',
#        'PHI', 'SAN', 'LAC', 'OKC', 'MIN', 'DET', 'IND', 'GOL', 'POR',
#        'ATL', 'BOS', 'DAL'], dtype=object)

# %%
df2 = df
df2["TEAM"] = df["TEAM"].astype(str)
df2["TEAM"].unique()
# Out:
# array(['TOR', 'MEM', 'MIA', 'BRO', 'NOR', 'MIL', 'CLE', 'LAL', 'ORL',
#        'HOU', 'WAS', 'PHO', 'UTA', 'SAC', 'CHA', 'CHI', 'NYK', 'DEN',
#        'PHI', 'SAN', 'LAC', 'OKC', 'MIN', 'DET', 'IND', 'GOL', 'POR',
#        'ATL', 'BOS', 'DAL'], dtype=object)

# %%
df2["TEAM"] = df2["TEAM"].replace(['GOL','NOR','BRO','SAN','PHO'],['GSW','NOP','BKN','SAS','PHX'])
df["TEAM"] = df2["TEAM"]
df["TEAM"].unique()
# Out:
# array(['TOR', 'MEM', 'MIA', 'BKN', 'NOP', 'MIL', 'CLE', 'LAL', 'ORL',
#        'HOU', 'WAS', 'PHX', 'UTA', 'SAC', 'CHA', 'CHI', 'NYK', 'DEN',
#        'PHI', 'SAS', 'LAC', 'OKC', 'MIN', 'DET', 'IND', 'GSW', 'POR',
#        'ATL', 'BOS', 'DAL'], dtype=object)

# %%
df
# Out:
#              FULL NAME TEAM  POS  AGE  GP   MPG  MIN%  USG%   TO%  FTA  ...  \
# 0     Precious Achiuwa  TOR    F   22  21  26.5  55.2  17.2  10.3   35  ...
# 1         Steven Adams  MEM    C   28  29  24.9  52.0  13.4  22.2   84  ...
# 2          Bam Adebayo  MIA  C-F   24  18  32.9  68.5  26.0  15.3  112  ...
# 3         Santi Aldama  MEM  F-C   20  16   9.7  20.3  20.6   6.6   12  ...
# 4    LaMarcus Aldridge  BKN  C-F   36  25  23.6  49.2  22.2   6.3   48  ...
# ..                 ...  ...  ...  ...  ..   ...   ...   ...   ...  ...  ...
# 476         Trae Young  ATL    G   23  28  34.2  71.2  34.7  15.0  173  ...
# 477     Omer Yurtseven  MIA    C   23  20   7.2  14.9  19.8  12.5   18  ...
# 478        Cody Zeller  POR  F-C   29  24  13.3  27.7  15.4  14.2   47  ...
# 479        Ivica Zubac  LAC    C   24  29  24.8  51.6  14.5  16.0   96  ...
# 480      Scottie Lewis  CHA    G   21   2   3.3   6.9   5.7   0.0    2  ...
#
# ...

# %%
df.to_csv('NBA Player Stats.csv')
